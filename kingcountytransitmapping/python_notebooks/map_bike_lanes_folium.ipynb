# %% [markdown]
# <a href="https://colab.research.google.com/github/TSGreenwood/tsgreenwood.github.io/blob/google_cloud/map_bike_lanes_folium.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Template for new colab notebook within Google Cloud Project**

# %%
# Set the current project in Google Cloud SDK to 'taragreenwoodpersonalwebsite'

# !gcloud config set project 'taragreenwoodpersonalwebsite'
# Out:
# Updated property [core/project].

# %%
# Connect notebook to my Drive account

from google.colab import auth
auth.authenticate_user()

# %%
# Most frequently used libraries

import geopandas as gpd
import folium
from folium import plugins

# %%
# Load dataset

bike_lanes_gdf = gpd.read_file('gs://kingcountypublictransit/data/bike_lanes.geojson')
bike_lanes_gdf.info()
bike_lanes_gdf.head()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 143876 entries, 0 to 143875
# Data columns (total 8 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   TLINK_ID    143876 non-null  object
#  1   EFFEC_DATE  143876 non-null  object
#  2   FR_TPOINT   143876 non-null  int64
#  3   TO_TPOINT   143876 non-null  int64
#  4   FULLNAME_R  143876 non-null  object
#  5   ROLL_LEN    143876 non-null  float64
#  6   Shape_Leng  143876 non-null  float64
#  7   geometry    143876 non-null  geometry
# dtypes: float64(2), geometry(1), int64(2), object(3)
# memory usage: 8.8+ MB
#   TLINK_ID  EFFEC_DATE  FR_TPOINT  TO_TPOINT    FULLNAME_R    ROLL_LEN  \
# 0     9537  1993-06-28     101697     101900    95th Ave S  342.410418
# 1   113165  1995-09-28       1585       1587   NE 200th Ct  153.300000
# 2    21455  1993-06-28     302912      92695    S 164th St   65.265000
# 3     9889  1993-06-28      86397     344665  178th Ave SE  268.068564
# 4   115925  1993-06-28      97983      98111     4th Ave S  214.350000
#
#    Shape_Leng                                           geometry
# 0  342.410418  LINESTRING (-122.21422 47.41899, -122.21422 47...
# 1  153.300073  LINESTRING (-122.30659 47.77427, -122.30597 47...
# 2   64.742908  LINESTRING (-122.27349 47.45626, -122.27323 47...
# 3  268.068564  LINESTRING (-122.10365 47.48038, -122.10364 47...
# 4  214.349847  LINESTRING (-122.32989 47.43516, -122.32998 47...
